# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached jax-0.5.0-py3-none-any.whl (2.3 MB)
# ...
#   Using cached jaxlib-0.5.0-cp311-cp311-manylinux2014_x86_64.whl (102.0 MB)
# ...
#   Attempting uninstall: jaxlib
#     Found existing installation: jaxlib 0.5.3
#     Uninstalling jaxlib-0.5.3:
#       Successfully uninstalled jaxlib-0.5.3
#   Attempting uninstall: jax
#     Found existing installation: jax 0.5.3
#     Uninstalling jax-0.5.3:
#       Successfully uninstalled jax-0.5.3
# ...

# %%
# !python ppo_training.py --num_epochs=10 --lr=3e-3
# Out:
# ERROR:2025-03-28 20:29:24,629:jax._src.xla_bridge:647: Jax plugin configuration error: Exception when calling jax_plugins.xla_cuda12.initialize()
# Traceback (most recent call last):
#   File "/home/oluwaseyi/wireless_optim/project/lib/python3.11/site-packages/jax/_src/xla_bridge.py", line 645, in discover_pjrt_plugins
#     plugin_module.initialize()
#   File "/home/oluwaseyi/wireless_optim/project/lib/python3.11/site-packages/jax_plugins/xla_cuda12/__init__.py", line 103, in initialize
#     triton.register_compilation_handler(
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'jax._src.lib.triton' has no attribute 'register_compilation_handler'
# Starting PPO training...
# PPO Epoch 0: Reward = 15386.75, Loss = 70.2955
# PPO Epoch 1: Reward = 15481.95, Loss = 8.6841
# PPO Epoch 2: Reward = 15420.50, Loss = 29073.3281
# PPO Epoch 3: Reward = 17160.24, Loss = 224.3400
# PPO Epoch 4: Reward = 17333.54, Loss = 3.9467
# PPO Epoch 5: Reward = 14276.29, Loss = 11.5495
# ...

# %%
# !python ppo_training.py --num_epochs=10000 --lr=1e-3 --gae_lambda=0.9 --update_epochs=50 --max_grad_norm=0.2

# %%
# !python dq3n_training.py --num_episodes=10
# Out:
# ERROR:2025-03-28 20:22:06,793:jax._src.xla_bridge:647: Jax plugin configuration error: Exception when calling jax_plugins.xla_cuda12.initialize()
# Traceback (most recent call last):
#   File "/home/oluwaseyi/wireless_optim/project/lib/python3.11/site-packages/jax/_src/xla_bridge.py", line 645, in discover_pjrt_plugins
#     plugin_module.initialize()
#   File "/home/oluwaseyi/wireless_optim/project/lib/python3.11/site-packages/jax_plugins/xla_cuda12/__init__.py", line 103, in initialize
#     triton.register_compilation_handler(
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'jax._src.lib.triton' has no attribute 'register_compilation_handler'
#
# Starting D3QN training...
# Starting D3QN training...
# Traceback (most recent call last):
#   File "/home/oluwaseyi/wireless_optim/project/lib/python3.11/site-packages/jax/_src/lax/lax.py", line 174, in _broadcast_shapes_uncached
#     return _try_broadcast_shapes(*rank_promoted_shapes, name='broadcast_shapes')
# ...

# %%
# !python plot_training.py
# Out:
# ERROR:2025-03-26 16:52:56,192:jax._src.xla_bridge:647: Jax plugin configuration error: Exception when calling jax_plugins.xla_cuda12.initialize()
# Traceback (most recent call last):
#   File "/home/oluwaseyi/wireless_optim/project/lib/python3.11/site-packages/jax/_src/xla_bridge.py", line 645, in discover_pjrt_plugins
#     plugin_module.initialize()
#   File "/home/oluwaseyi/wireless_optim/project/lib/python3.11/site-packages/jax_plugins/xla_cuda12/__init__.py", line 103, in initialize
#     triton.register_compilation_handler(
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'jax._src.lib.triton' has no attribute 'register_compilation_handler'

# %%
# !python offline_d3qn_training.py
# Out:
# python: can't open file '/home/oluwaseyi/wireless_optim/offline_d3qn_training.py': [Errno 2] No such file or directory
